# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %matplotlib widget

# %%
from test import Test
from extractor import Extractor

# %% [markdown]
# ## Data Extractor

# %%
data = Extractor('./../raw_data/coincidence/wave*', 0, 2)

# %%
data.extractor(['Amplitude'])
# Out:
#       Amplitude CH: 0  Amplitude CH: 2
# 0           -0.028240        -0.077967
# 1           -0.031686        -0.095980
# 2           -0.081790        -0.036488
# 3           -0.052038        -0.030346
# 4           -0.054320        -0.041261
# ...               ...              ...
# 2495        -0.030558        -0.153735
# 2496        -0.068261        -0.028633
# 2497        -0.049075        -0.143664
# 2498        -0.100470        -0.048554
# 2499        -0.032552        -0.195088
#
# [2500 rows x 2 columns]

# %%
data.sampling_period()
# Out:
# (312.5, 'ps')

# %% [markdown]
# ## Wave forms

# %%
from waveForms import Signal_analyzer

# %%
signals = Signal_analyzer('./../raw_data/boards_char/wavecatcher_run171_Ascii.dat', 4)

# %%
signals.noise(graph=True)
# Out:
#              statistics
# mean [V]         0.0000
# std [V]          0.0012
# 5 sigma [V]      0.0060

# %%
signals.noise(graph=True)
# Out:
#              statistics
# mean [V]         0.0000
# std [V]          0.0012
# 5 sigma [V]      0.0060

# %%
signals.signal_plot(0, 50)

# %% [markdown]
# ## Amplitude Analysis

# %%
from amplitude import Amplitude_analyzer

# %%
amplitude_0 = Amplitude_analyzer('./../raw_data/coincidence/wavecatcher_run142_Ascii.dat', 0)
amplitude_1 = Amplitude_analyzer('./../raw_data/coincidence/wavecatcher_run142_Ascii.dat_0001', 0)
amplitude = Amplitude_analyzer('./../raw_data/coincidence/*', 0, 2)

# %%
amplitude.data
# Out:
#       Amplitude_ch0  Amplitude_ch2
# 0         -0.028240      -0.077967
# 1         -0.031686      -0.095980
# 2         -0.081790      -0.036488
# 3         -0.052038      -0.030346
# 4         -0.054320      -0.041261
# ...             ...            ...
# 2495      -0.030558      -0.153735
# 2496      -0.068261      -0.028633
# 2497      -0.049075      -0.143664
# 2498      -0.100470      -0.048554
# 2499      -0.032552      -0.195088
#
# [2500 rows x 2 columns]

# %%
amplitude.histo_channels(0, 2, flip=True)

# %%
Amplitude_analyzer.histo_runs(amplitude_0, amplitude_1, channel=0, flip=True, labels=['T1', 'T2'], title='Plastico 1')

# %%
amplitude.modes
# Out:
# {'Amplitude_ch0': 0.02865169, 'Amplitude_ch2': 0.0319394}

# %%
amplitude.stats()
# Out:
#       Amplitude_ch0  Amplitude_ch2
# mean         -0.074         -0.078
# std           0.059          0.066
# Mode          0.029          0.032

# %%
amplitude = Amplitude_analyzer('./../raw_data/boards_char/*', 4)

# %%
amplitude.histo_channels(4, flip=True)

# %%
amplitude.stats()
# Out:
#       Amplitude_ch4
# mean         -0.337
# std           0.148
# Mode          0.211

# %% [markdown]
# ## Charge Analysis

# %%
from charge import Charge_analyzer

charge_0 = Charge_analyzer('./../raw_data/coincidence/wavecatcher_run142_Ascii.dat', 0)
charge_1 = Charge_analyzer('./../raw_data/coincidence/wavecatcher_run142_Ascii.dat_0001', 0)
charge = Charge_analyzer('./../raw_data/coincidence/*', 0, 2)

# %%
charge_0.data
# Out:
#      Charge_ch0
# 0        -7.068
# 1       -14.756
# 2       -93.733
# 3       -76.672
# 4       -25.696
# ..          ...
# 495     -96.105
# 496    -146.600
# 497     -80.489
# 498    -117.947
# 499     -45.169
#
# [500 rows x 1 columns]

# %%
charge.histo_channels(0, 2, flip = True)

# %%
charge.stats()
# Out:
#       Charge_ch0  Charge_ch2
# mean     -79.495     -92.240
# std       70.503      85.193
# Mode      32.718      38.502

# %%
Charge_analyzer.histo_runs(charge_0, charge_1, channel = 0, flip=True, labels=['T1', 'T2'], title='Plastico 3')
